# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
ola = pd.read_csv("Ola Customer Reviews.csv")

# %%
uber = pd.read_csv("Uber Customer Reviews.csv")

# %%
ola.head()
# Out:
#         source                             review_id         user_name  \
# 0  Google Play  fbc7ffc9-5a89-446e-87fd-d69bf4a7f984     Puipuii Ralte
# 1  Google Play  5a0051fb-220a-45b2-ba94-a15a2949218f      Deepak Kumar
# 2  Google Play  71ebf933-b734-474d-bb65-a18c90906ed2  Ahamed Azarudeen
# 3  Google Play  e1cc0010-60b3-4126-99c2-e8549088566a        Rahil Syed
# 4  Google Play  77cf1be1-b428-4493-ae25-e0f288f79b8f           vin 007
#
#   review_title                                 review_description  rating  \
# 0          NaN  The map in Ola is so messed up, i have to pay ...       1
# 1          NaN                            Deepak Kumar.... 🙏🙏🙏🙏🙏]       5
# 2          NaN  Such aa irresponsible app more then I waiting ...       1
# 3          NaN                                              Worst       1
# 4          NaN  Too much expensive .. try UBer... They are pro...       1
#
#    thumbs_up          review_date developer_response developer_response_date  \
# ...

# %%
uber.head()
# Out:
#         source                             review_id        user_name  \
# 0  Google Play  18d6584c-d0e9-4833-a744-f607058aee97        Milky Way
# 1  Google Play  50a08f18-cece-4ddf-b617-028844c8aa28   Bradlee Severa
# 2  Google Play  b0d8e75a-80a7-4dcd-abaf-72b046dbeeb7    Amit Aggarwal
# 3  Google Play  502702a9-25ed-4373-a96c-7fa1f06caacd     Bryant Inman
# 4  Google Play  f47a3fb6-23db-49bd-9e63-f33c8d724d07  Addie Whittaker
#
#   review_title                                 review_description  rating  \
# 0          NaN  Suddenly, the driver can't have my location an...       1
# 1          NaN  Very cordial.. And helped with a quick turnaro...       5
# 2          NaN                               Very good experience       5
# 3          NaN                                          All I use       5
# 4          NaN  I have enjoyed traveling by Uber my drivers ha...       5
#
#    thumbs_up          review_date developer_response developer_response_date  \
# ...

# %%
ola.shape
# Out:
# (357698, 13)

# %%
uber.shape
# Out:
# (1069616, 13)

# %%
ola.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357698 entries, 0 to 357697
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   source                   357698 non-null  object
#  1   review_id                357698 non-null  object
#  2   user_name                357698 non-null  object
#  3   review_title             891 non-null     object
#  4   review_description       357682 non-null  object
#  5   rating                   357698 non-null  int64
#  6   thumbs_up                356807 non-null  float64
#  7   review_date              357698 non-null  object
#  8   developer_response       124769 non-null  object
#  9   developer_response_date  124590 non-null  object
#  10  appVersion               275326 non-null  object
#  11  laguage_code             357698 non-null  object
#  12  country_code             357698 non-null  object
# dtypes: float64(1), int64(1), object(11)
# ...

# %%
uber.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1069616 entries, 0 to 1069615
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   source                   1069616 non-null  object
#  1   review_id                1069616 non-null  object
#  2   user_name                1069615 non-null  object
#  3   review_title             2180 non-null     object
#  4   review_description       1069501 non-null  object
#  5   rating                   1069616 non-null  int64
#  6   thumbs_up                1067436 non-null  float64
#  7   review_date              1069616 non-null  object
#  8   developer_response       198264 non-null   object
#  9   developer_response_date  197278 non-null   object
#  10  appVersion               828068 non-null   object
#  11  laguage_code             1069616 non-null  object
#  12  country_code             1069616 non-null  object
# ...

# %%
ola.describe()
# Out:
#              rating      thumbs_up
# count  357698.00000  356807.000000
# mean        2.77325       0.883461
# std         1.85194      16.417954
# min         1.00000       0.000000
# 25%         1.00000       0.000000
# 50%         2.00000       0.000000
# 75%         5.00000       0.000000
# max         5.00000    2788.000000

# %%
uber.describe()
# Out:
#              rating     thumbs_up
# count  1.069616e+06  1.067436e+06
# mean   3.650441e+00  8.954054e-01
# std    1.743725e+00  2.042451e+01
# min    1.000000e+00  0.000000e+00
# 25%    1.000000e+00  0.000000e+00
# 50%    5.000000e+00  0.000000e+00
# 75%    5.000000e+00  0.000000e+00
# max    5.000000e+00  5.572000e+03

# %%
average_rating_ola = ola['rating'].mean()
print("Average Rating of Ola",average_rating_ola)
# Out:
# Average Rating of Ola 2.7732500601065704

# %%
average_rating_uber = uber['rating'].mean()
print("Average Rating of Uber",average_rating_uber)
# Out:
# Average Rating of Uber 3.6504409058952

# %%
print(ola.isnull().sum())
print(uber.isnull().sum())
# Out:
# source                          0
# review_id                       0
# user_name                       0
# review_title               356807
# review_description             16
# rating                          0
# thumbs_up                     891
# review_date                     0
# developer_response         232929
# developer_response_date    233108
# appVersion                  82372
# laguage_code                    0
# country_code                    0
# dtype: int64
# source                           0
# review_id                        0
# user_name                        1
# review_title               1067436
# review_description             115
# rating                           0
# thumbs_up                     2180
# review_date                      0
# developer_response          871352
# developer_response_date     872338
# appVersion                  241548
# laguage_code                     0
# country_code                     0
# dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
sns.countplot(x='rating',data =ola)
plt.title("ola Ratings Distribution")

plt.subplot(1,2,2)
sns.countplot(x='rating',data = uber)
plt.title("uber ratings distribution")

plt.tight_layout()
plt.show()

# %%
pip install pandas textblob seaborn matplotlib
# Out:
# ...
#      -------------------------------------- 626.3/626.3 kB 1.9 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.5/1.5 MB 5.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nltk
#     Found existing installation: nltk 3.7
#     Uninstalling nltk-3.7:
#       Successfully uninstalled nltk-3.7
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

def get_sentiment(text):
    analysis = TextBlob(str(text))
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'
    
ola['sentiment'] = ola['review_description'].apply(get_sentiment)
uber['sentiment'] = uber['review_description'].apply(get_sentiment)

plt.figure(figsize = (10,6))

plt.subplot(1,2,1)
sns.countplot(x='sentiment',data = ola)
plt.title('Ola Sentiment Analysis')

plt.subplot(1,2,2)
sns.countplot(x='sentiment',data = uber)
plt.title("Uber sentiment Analysis")

plt.tight_layout()
plt.show()

# %%
ola['sentiment'] = ola['developer_response'].apply(get_sentiment)
uber['sentiment'] = uber['developer_response'].apply(get_sentiment)

plt.figure(figsize = (10,6))

plt.subplot(1,2,1)
sns.countplot(x='sentiment',data = ola)
plt.title('ola sentiment Analysis')

plt.subplot(1,2,2)
sns.countplot(x='sentiment',data = uber)
plt.title("uber sentiment Analysis")

plt.tight_layout()
plt.show()

# %%
ola_source_counts = ola['source'].value_counts()
uber_source_counts = uber['source'].value_counts()

ola_colors = ['#FF5733', '#FFC300', '#DAF7A6', '#C70039', '#900C3F', '#581845', '#28B463', '#FF5733']
uber_colors = ['#1ABC9C', '#2ECC71', '#3498DB', '#9B59B6', '#E74C3C', '#F1C40F', '#E67E22', '#ECF0F1']

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.pie(ola_source_counts, labels=ola_source_counts.index, autopct='%1.1f%%', startangle=140,colors = ola_colors)
plt.title('Distribution of Sources - Ola')

plt.subplot(1, 2, 2)
plt.pie(uber_source_counts, labels=uber_source_counts.index, autopct='%1.1f%%', startangle=140,colors = uber_colors)
plt.title('Distribution of Sources - Uber')

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Example data for testing (comment this out when running with actual data)
# ola = pd.DataFrame({'review_date': ['2024-01-01', '2024-01-02', '2024-01-03'], 'review': [5, 3, 4]})
# uber = pd.DataFrame({'review_date': ['2024-01-01', '2024-01-02', '2024-01-04'], 'review': [2, 5, 3]})

# Check if 'review_date' exists in both DataFrames
if 'review_date' in ola.columns and 'review_date' in uber.columns:
    # Convert review_date to datetime format
    ola['review_date'] = pd.to_datetime(ola['review_date'], errors='coerce')
    uber['review_date'] = pd.to_datetime(uber['review_date'], errors='coerce')
    
    # Drop rows with NaT values after conversion
    ola.dropna(subset=['review_date'], inplace=True)
    uber.dropna(subset=['review_date'], inplace=True)
    
    # Set review_date as the index
    ola.set_index('review_date', inplace=True)
    uber.set_index('review_date', inplace=True)
    
    # Resample data to get a daily count of reviews
    ola_daily_review_counts = ola.resample('D').size()
    uber_daily_review_counts = uber.resample('D').size()
    
    # Plot time series of daily review counts for Ola
    plt.figure(figsize=(10, 6))
    ola_daily_review_counts.plot(marker='o')
    plt.title('Daily Review Counts - Ola')
    plt.xlabel('Date')
    plt.ylabel('Number of Reviews')
    plt.grid(True)
    plt.show()
    
    # Plot time series of daily review counts for Uber
    plt.figure(figsize=(10, 6))
    uber_daily_review_counts.plot(marker='o')
    plt.title('Daily Review Counts - Uber')
    plt.xlabel('Date')
    plt.ylabel('Number of Reviews')
    plt.grid(True)
    plt.show()
else:
    print("Error: 'review_date' column is missing in one or both DataFrames.")
# Out:
# Error: 'review_date' column is missing in one or both DataFrames.

# %%
# !pip install wordcloud
# Out:
# ...
#      -------------------------------------- 300.6/300.6 kB 1.4 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# Load the data
ola_reviews = pd.read_csv("Ola Customer Reviews.csv")
uber_reviews = pd.read_csv("Uber Customer Reviews.csv")

# %%
ola_info = ola_reviews.info()
uber_info = uber_reviews.info()

# Check for missing values in both datasets
ola_missing = ola_reviews.isnull().sum()
uber_missing = uber_reviews.isnull().sum()

# Check the number of unique values in each column
ola_unique = ola_reviews.nunique()
uber_unique = uber_reviews.nunique()

ola_info, uber_info, ola_missing, uber_missing, ola_unique, uber_unique
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357698 entries, 0 to 357697
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   source                   357698 non-null  object
#  1   review_id                357698 non-null  object
#  2   user_name                357698 non-null  object
#  3   review_title             891 non-null     object
#  4   review_description       357682 non-null  object
#  5   rating                   357698 non-null  int64
#  6   thumbs_up                356807 non-null  float64
#  7   review_date              357698 non-null  object
#  8   developer_response       124769 non-null  object
#  9   developer_response_date  124590 non-null  object
#  10  appVersion               275326 non-null  object
#  11  laguage_code             357698 non-null  object
#  12  country_code             357698 non-null  object
# dtypes: float64(1), int64(1), object(11)
# ...

# %%
from wordcloud import WordCloud
from nltk.corpus import stopwords
import nltk

# Download the stopwords from nltk
nltk.download('stopwords')

# Define a function to create a word cloud
def create_word_cloud(text):
    # Define the stopwords
    stop_words = set(stopwords.words('english'))
    
    # Create the word cloud
    wordcloud = WordCloud(width=800, height=400, background_color='white', 
                          stopwords=stop_words, max_words=100).generate(text)
    
    # Plot the word cloud
    plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis('off')
    plt.show()

# Categorize the reviews into positive, neutral, and negative
ola_reviews['sentiment'] = ola_reviews['rating'].apply(lambda x: 'positive' if x >= 4 else 'neutral' if x == 3 else 'negative')
uber_reviews['sentiment'] = uber_reviews['rating'].apply(lambda x: 'positive' if x >= 4 else 'neutral' if x == 3 else 'negative')

# Combine the review descriptions into a single text for each category
ola_positive_reviews = ' '.join(ola_reviews[ola_reviews['sentiment'] == 'positive']['review_description'].dropna())
ola_neutral_reviews = ' '.join(ola_reviews[ola_reviews['sentiment'] == 'neutral']['review_description'].dropna())
ola_negative_reviews = ' '.join(ola_reviews[ola_reviews['sentiment'] == 'negative']['review_description'].dropna())

# Create a word cloud for each category of Ola reviews
print('Ola Positive Reviews:')
create_word_cloud(ola_positive_reviews)

print('Ola Neutral Reviews:')
create_word_cloud(ola_neutral_reviews)

print('Ola Negative Reviews:')
create_word_cloud(ola_negative_reviews)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\shubh\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Ola Positive Reviews:
# Ola Neutral Reviews:
# Ola Negative Reviews:

# %%
ola_reviews['developer_response_present'] = ola_reviews['developer_response'].notna()
uber_reviews['developer_response_present'] = uber_reviews['developer_response'].notna()

# Calculate the average number of thumbs up for reviews with and without a developer response
ola_avg_thumbs_up = ola_reviews.groupby('developer_response_present')['thumbs_up'].mean()
uber_avg_thumbs_up = uber_reviews.groupby('developer_response_present')['thumbs_up'].mean()

ola_avg_thumbs_up, uber_avg_thumbs_up
# Out:
# (developer_response_present
#  False    0.835490
#  True     0.972871
#  Name: thumbs_up, dtype: float64,
#  developer_response_present
#  False    0.638500
#  True     2.028569
#  Name: thumbs_up, dtype: float64)

# %%
# !pip install scikit-multilearn
# Out:
# ...
#      -------------------------------------- 89.4/89.4 kB 850.8 kB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import nltk
import re
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
from wordcloud import WordCloud,STOPWORDS
from nltk.stem.snowball import SnowballStemmer
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.metrics import f1_score
from sklearn.metrics import hamming_loss
from skmultilearn.problem_transform import BinaryRelevance
from sklearn.naive_bayes import MultinomialNB
from skmultilearn.problem_transform import ClassifierChain
from skmultilearn.problem_transform import LabelPowerset

# %%
# Set the aesthetic style of the plots
sns.set_style("whitegrid")

# Create a figure with two subplots
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

# Plot the distribution of ratings for Ola
sns.countplot(x='rating', data=ola_reviews, palette='viridis', ax=axes[0])
axes[0].set_title('Ola Ratings Distribution')
axes[0].set_xlabel('Rating')
axes[0].set_ylabel('Frequency')

# Plot the distribution of ratings for Uber
sns.countplot(x='rating', data=uber_reviews, palette='viridis', ax=axes[1])
axes[1].set_title('Uber Ratings Distribution')
axes[1].set_xlabel('Rating')
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
ola_country_counts = ola_reviews['country_code'].value_counts().head(10)
uber_country_counts = uber_reviews['country_code'].value_counts().head(10)

# Create a bar plot of the review counts for the top 10 countries
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

ola_country_counts.plot(kind='bar', ax=axes[0], color='b')
axes[0].set_title('Ola Reviews by Country')
axes[0].set_xlabel('Country Code')
axes[0].set_ylabel('Number of Reviews')

uber_country_counts.plot(kind='bar', ax=axes[1], color='r')
axes[1].set_title('Uber Reviews by Country')
axes[1].set_xlabel('Country Code')
axes[1].set_ylabel('Number of Reviews')

plt.tight_layout()
plt.show()

# %%
ola_app_version_counts = ola_reviews['appVersion'].value_counts().head(10)
uber_app_version_counts = uber_reviews['appVersion'].value_counts().head(10)

# Create a bar plot of the review counts for the top 10 app versions
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

ola_app_version_counts.plot(kind='bar', ax=axes[0], color='b')
axes[0].set_title('Ola Reviews by App Version')
axes[0].set_xlabel('App Version')
axes[0].set_ylabel('Number of Reviews')

uber_app_version_counts.plot(kind='bar', ax=axes[1], color='r')
axes[1].set_title('Uber Reviews by App Version')
axes[1].set_xlabel('App Version')
axes[1].set_ylabel('Number of Reviews')

plt.tight_layout()
plt.show()

# %% [markdown]
# The bar plots illustrate the distribution of reviews across different app versions for both Ola and Uber.
#
# For Ola, the app version with the highest number of reviews is 5.6.3, followed by versions 5.5.6 and 5.4.1. In the case of Uber, version 4.358.10003 has the most reviews, with versions 4.357.10002 and 4.355.10002 coming next.
#
# Notably, for both Ola and Uber, there is a marked decline in the number of reviews after the top three app versions. This trend may suggest that users are more inclined to leave reviews when they initially install the app or following a major update.
